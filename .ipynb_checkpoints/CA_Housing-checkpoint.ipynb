# %%
# Import data manipulation modules
import pandas as pd
import os
import numpy as np
import seaborn as sns
from pydataset import data

# Import data visualization modules
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams
from bs4 import BeautifulSoup
from pandas.plotting import scatter_matrix

# %%
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing(as_frame=True)
df = housing['data'].join(housing['target'])
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
#check the records
len(df)
# Out:
# 20640

# %%
#Check the first 5 records
df[:5]
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
#Check the columns
df.columns.tolist()
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude',
#  'MedHouseVal']

# %%
# Count total NaN at each column in  DataFrame
print(" \nCount total NaN at each column in a DataFrame : \n\n",
      df.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
#Count null values for each colum
[[column,df[column].isnull().sum()] for column in df.columns]
# Out:
# [['MedInc', 0],
#  ['HouseAge', 0],
#  ['AveRooms', 0],
#  ['AveBedrms', 0],
#  ['Population', 0],
#  ['AveOccup', 0],
#  ['Latitude', 0],
#  ['Longitude', 0],
#  ['MedHouseVal', 0]]

# %%
#Check how many rows in reach column
df.count()
# Out:
# MedInc         20640
# HouseAge       20640
# AveRooms       20640
# AveBedrms      20640
# Population     20640
# AveOccup       20640
# Latitude       20640
# Longitude      20640
# MedHouseVal    20640
# dtype: int64

# %%
#Check data types
df.dtypes
# Out:
# MedInc         float64
# HouseAge       float64
# AveRooms       float64
# AveBedrms      float64
# Population     float64
# AveOccup       float64
# Latitude       float64
# Longitude      float64
# MedHouseVal    float64
# dtype: object

# %%
#Grab general knowledge of data
df.describe(include='all')
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df.hist(bins=50, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (9, 7))
plt.scatter(df.Latitude, df.Longitude, alpha = 0.2, c= df.MedHouseVal, s = df.Population/100)
plt.colorbar()

# %%
#Dense populated areas that have high home values between North Cali and South Cali
